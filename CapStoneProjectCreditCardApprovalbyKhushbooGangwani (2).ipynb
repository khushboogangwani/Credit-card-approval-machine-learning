# %% [markdown]
# # **Credit-Card-Approval-Rate-Prediction**

# %% [markdown]
# # **Introduction**
#
#
# In the ever-evolving landscape of banking, the efficient evaluation of credit card applicants is paramount. My project delves into the world of predictive analytics and machine learning to enhance the credit approval process. Focusing on a dataset encompassing diverse customer attributes, I aim to answer critical questions surrounding income, gender, assets, education, and marital status in relation to credit card approval. By leveraging data-driven insights, My objective is to revolutionize the credit scoring model, providing banks with a robust tool to make informed decisions, mitigate risks, and ultimately shape the future of credit assessment in the financial sector.

# %% [markdown]
# # **Attributes** **Description**

# %% [markdown]
# **CREDIT** **CARD** **APPROVAL** **RATE** **PREDICTION**
#
# The dataset consists of following csv files :
# Features name: (Credit_Card.csv)
#
# 1. Ind_ID: Client ID
# 2. Gender: Gender information
# 3. Car_owner: Having car or not
# 4. Propert_owner: Having property or not
# 5. Children: Count of children
# 6. Annual_income: Annual income
# 7. Type_Income: Income type
# 8. Education: Education level
# 9. Marital_status: Marital_status
# 10. Housing_type: Living style
# 11. Birthday_count: Use backward count from current day (0), -1 means yesterday.
# 12. Employed_days: Start date of employment. Use backward count from current day (0).
# Positive value means, individual is currently unemployed.
# 13. Mobile_phone: Any mobile phone
# 14. Work_phone: Any work phone
# 15. Phone: Any phone number
# 16. EMAIL_ID: Any email ID
# 17. Type_Occupation: Occupation
# 18. Family_Members: Family size
#
# **Another data set (Credit_card_label.csv) contains two key pieces of information**
# 1. ID: The joining key between application data and credit status data, same is Ind_ID
# 2. Label: 0 is application approved and 1 is application rejected.

# %% [markdown]
# # **Section** **1**: **Questions** **to** **Answer**

# %% [markdown]
# 1. **Why** **is** **your** **proposal** **important** **in** **today’s** **world**? **How** **predicting** **a** **good** **client** **is** **worthy** **for** **a** **bank**?
#
# In today's dynamic financial landscape, the significance of predicting a good client cannot be overstated. As banks strive for stability and growth, the ability to accurately assess creditworthiness becomes a linchpin for success. Our proposal addresses the crucial need for a robust credit approval system, utilizing predictive analytics and machine learning. By deciphering patterns within customer data, banks can make informed decisions, mitigating risks associated with credit card issuance. This not only safeguards the financial health of the institution but also enhances customer satisfaction by tailoring credit offerings to individuals who can responsibly manage their finances. In essence, our proposal aligns with the contemporary imperative for smart, data-driven banking practices that foster sustainable growth and customer trust.
#
# **2. How is it going to impact the banking sector?**
#
#   a). **Operational Efficiency:** Our proposal introduces advanced analytics and machine learning, streamlining credit assessment processes. This operational efficiency reduces manual efforts, allowing banks to make quicker and more accurate credit decisions.
#
#   b). **Enhanced Customer Experience:** The expedited credit approval process improves the overall customer experience. Clients benefit from faster responses and a more tailored approach to credit offerings, fostering satisfaction and loyalty.
#
#   c). **Risk Mitigation:** The adoption of predictive analytics minimizes the risk of defaults by accurately assessing creditworthiness. This, in turn, fortifies the financial stability of banks, reducing the impact of non-performing loans on their balance sheets.
#
#  d). **Portfolio Optimization:** The refined credit scoring model enables banks to optimize their lending portfolios. By identifying and targeting creditworthy individuals, institutions can strategically diversify their offerings, maximizing profitability.
#
#   e). **Innovation Leadership:** Embracing data-driven decision-making positions banks as innovators in the financial sector. This proactive stance not only ensures adaptability to industry changes but also instills confidence in customers, reinforcing the institution's reputation for forward-thinking and resilient practices.
#
#
# **3. If any, what is the gap in the knowledge or how your proposed method can be helpful if required in future for any bank in India.**
#
#  In the realm of credit assessment, a crucial knowledge gap exists in traditional methods that may not capture the full spectrum of an individual's creditworthiness. Our proposed method, utilizing advanced analytics and machine learning, aims to address this gap by providing a more nuanced and dynamic evaluation of applicants. This approach takes into account diverse factors such as income type, gender, assets, education, and marital status, offering a comprehensive understanding of an applicant's financial profile.
#
#  **How our Proposed Method Fills the Knowledge Gap for Future Banks in India:**
#
#  a. **Personalized Insights:** Our method generates personalized insights, going beyond conventional credit scoring models. This ensures a more accurate and tailored evaluation of an individual's creditworthiness, considering unique socio-economic factors prevalent in India.
#
#  b. **Scalability:** As the financial landscape evolves, our proposed method offers scalability. It can seamlessly incorporate new data sources and adapt to changing economic conditions, providing a future-proof solution for banks in India.
#
#  c. **Adaptability to Emerging Trends:** The predictive nature of our approach empowers banks to stay ahead of emerging trends. By leveraging historical data and predictive analytics, institutions can make informed decisions that align with the evolving dynamics of the Indian market.
#
#  d. **Risk Mitigation:** The method's comprehensive evaluation reduces the risk of defaults by capturing subtle indicators of creditworthiness. This proactive risk mitigation strategy enhances the financial stability of banks, especially crucial in the ever-changing Indian economic landscape.
#
#  e. **Aligning with Regulatory Changes:** Given the dynamic nature of regulatory changes in the Indian banking sector, our method ensures compliance by adapting to evolving requirements. Its flexibility allows banks to seamlessly incorporate regulatory adjustments, fostering a robust and compliant credit assessment framework for the future.

# %% [markdown]
# # **Section 2: Initial Hypothesis (or hypotheses)**

# %% [markdown]
# 1. **Car Owners' Credit Card Approval Hypothesis:**
#    - *Assumption:* Individuals owning cars are more likely to have their credit card applications approved.
#
# 2. **Income Influence Hypothesis:**
#    - *Assumption:* There is a positive correlation between higher annual income and credit card approval.
#
#
# 3. **Educational Impact Hypothesis:**
#    - *Assumption:* Individuals with a higher education level are less likely to face credit card application rejections.
#
# 4. **Employment Duration Hypothesis:**
#    - *Assumption:* A shorter duration of employment may lead to lower credit card approval rates.
#
#
# 5. **Demographic Factors and Credit Approval Hypothesis:**
#    - *Assumption:* Demographic factors such as gender and marital status impact credit card approval rates.

# %% [markdown]
# # **Section** **3**: **Data** **analysis** **and cleaning**

# %%
# importing the important libraries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# reading the datasets which include 2 csv files
df1= pd.read_csv("/content/Credit_card.csv")
df2= pd.read_csv("/content/Credit_card_label.csv")

# %%
# merging the both datasets and doing EDA
df= pd.merge(df1,df2,on="Ind_ID")

# %%
#what is the size of data
df.shape
# Out:
# (1548, 19)

# %%
#what data looks like
df.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
# what are the colums and itsdata type
df.info()
''' we have total 19 columns in which 16 are categorical and remaining three
 which includes annual_income, Birthday counts and employed days are continuous'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Ind_ID', 'GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN',
#        'Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status',
#        'Housing_type', 'Birthday_count', 'Employed_days', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'EMAIL_ID', 'Type_Occupation', 'Family_Members',
#        'label'],
#       dtype='object')

# %%
#renaming the features
df.rename(columns={'GENDER':'Gender','Propert_Owner':'Property_owner','CHILDREN':'Children',
'Type_Income':'Income_type','EDUCATION':'Education','EMAIL_ID':'Email_ID',
'Type_Occupation':'Occupation_type'}, inplace= True)

# %%
df.columns
# Out:
# Index(['Ind_ID', 'Gender', 'Car_Owner', 'Property_owner', 'Children',
#        'Annual_income', 'Income_type', 'Education', 'Marital_status',
#        'Housing_type', 'Birthday_count', 'Employed_days', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'Email_ID', 'Occupation_type', 'Family_Members',
#        'label'],
#       dtype='object')

# %%
# exploring the missing values
df.isnull().sum()
# Out:
# Ind_ID               0
# Gender               7
# Car_Owner            0
# Property_owner       0
# Children             0
# Annual_income       23
# Income_type          0
# Education            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# Email_ID             0
# Occupation_type    488
# Family_Members       0
# label                0
# dtype: int64

# %%
# visualisation of missing values using SNS library
fig, ax = plt.subplots(figsize=(12,6))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Missing values are their in the below columns:
#
# 1.Gender
#
# 2.Annual_income
#
# 3.Occupation_type
#
# 4.Birthday_count

# %%
# Creating new column by dividing the birthday_count with 365, by which we get age in years
df['Age_in_years'] = np.abs((df['Birthday_count'])/365)
df['Age_in_years'].sample(5)
# Out:
# 641     58.739726
# 301     37.986301
# 1043    39.712329
# 911     30.701370
# 853     38.383562
# Name: Age_in_years, dtype: float64

# %%
# Checking if there are any employed_days > 0
df[df['Employed_days']>0].shape
# Out:
# (261, 20)

# %%
# Crearting new column which gives experience in years by dividing employed_days with 365
df['Experience_years']= np.abs(df['Employed_days'])/365
df['Experience_years'].sample(5)
# Out:
# 329     1000.665753
# 1216       5.139726
# 1340       5.545205
# 501       22.712329
# 1412       0.468493
# Name: Experience_years, dtype: float64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Ind_ID Gender Car_Owner Property_owner  Children  Annual_income  \
# 0     5008827      M         Y              Y         0       180000.0
# 1     5009744      F         Y              N         0       315000.0
# 2     5009746      F         Y              N         0       315000.0
# 3     5009749      F         Y              N         0            NaN
# 4     5009752      F         Y              N         0       315000.0
# ...       ...    ...       ...            ...       ...            ...
# 1543  5028645      F         N              Y         0            NaN
# 1544  5023655      F         N              N         0       225000.0
# 1545  5115992      M         Y              Y         2       180000.0
# 1546  5118219      M         Y              N         0       270000.0
# 1547  5053790      F         Y              Y         0       225000.0
#
#                Income_type                      Education  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# so we dont have any duplicate values in this dataset

# %% [markdown]
# # Section 4: Exploratory data analysis

# %%
df
# Out:
#        Ind_ID Gender Car_Owner Property_owner  Children  Annual_income  \
# 0     5008827      M         Y              Y         0       180000.0
# 1     5009744      F         Y              N         0       315000.0
# 2     5009746      F         Y              N         0       315000.0
# 3     5009749      F         Y              N         0            NaN
# 4     5009752      F         Y              N         0       315000.0
# ...       ...    ...       ...            ...       ...            ...
# 1543  5028645      F         N              Y         0            NaN
# 1544  5023655      F         N              N         0       225000.0
# 1545  5115992      M         Y              Y         2       180000.0
# 1546  5118219      M         Y              N         0       270000.0
# 1547  5053790      F         Y              Y         0       225000.0
#
#                Income_type                      Education  \
# ...

# %%
cols = ['Gender', 'Car_Owner', 'Property_owner']
# Set up the figure and axes
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))
# Plot univariate distributions for each column
for i, col in enumerate(cols):
    sns.countplot(data=df, x=col, ax=axes[i])
    axes[i].set_title(f'Distribution of {col}', fontsize=18)
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x')
    axes[i].grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# The dataset displays a higher representation of females, suggesting that either more females are applying for credit cards.
# A notable majority of individuals in the dataset do not own a car, which could be attributed to mutiple factors like personal choices
# etc.
# Most individuals in the dataset are property owners, indicating that property ownership, might be a significant factor in credit card
# approval decisions.

# %%
cols = ['Children', 'Annual_income', 'Income_type']
# Set up the figure and axes
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))
# Plot univariate distributions for each column
for i, col in enumerate(cols):
  if df[col].dtype in ['int64', 'float64']:
    sns.histplot(data=df, x=col, ax=axes[i], bins=30, kde=True)
  else:
    sns.countplot(data=df, x=col, ax=axes[i], order=df[col].value_counts().index)
    axes[i].set_title(f'Distribution of {col}', fontsize=18)
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x')
    axes[i].grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Most individuals in the dataset either have no children or just one, with a decreasing number of individuals having two or more
# children.
# The annual income distribution is predominantly right-skewed, suggesting that most individuals have a lower to medium income, with
# a few outliers in the higher income bracket.
# Regarding income type, "Working" is the predominant category, succeeded by "Commercial associate" and "Pensioner", while
# categories like "State servant" have fewer representatives.

# %%
cols = ['Education', 'Marital_status', 'Housing_type']
# Set up the figure and axes
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))
# Plot univariate distributions for each column
for i, col in enumerate(cols):
  sns.countplot(data=df, x=col, ax=axes[i], order=df[col].value_counts().index)
  axes[i].set_title(f'Distribution of {col}', fontsize = 17)
  axes[i].set_ylabel('Count')
  axes[i].tick_params(axis='x', rotation = 45)
  axes[i].grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# In terms of education, the dataset predominantly consists of individuals with a "Secondary / secondary special" education level, akin
# to high school. While a significant number have "Higher education", fewer individuals fall into categories like "Incomplete higher" and
# "Lower secondary", and only a small fraction possess an "Academic degree" signifying advanced academic qualifications.
# When observing marital status, most individuals are "Married", with other statuses such as "Single / not married", "Civil marriage",
# "Separated", and "Widow" appearing in descending order of frequency.
# As for housing, the majority reside in a "House / apartment", with other housing arrangements like "With parents", "Municipal
# apartment", and "Rented apartment" being less frequent. The dataset contains very few individuals living in "Office apartment" or
# "Co-op apartment"

# %%
cols = ['Work_Phone', 'Phone', 'Email_ID']
# Set up the figure and axes
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))
# Plot univariate distributions for each column
for i, col in enumerate(cols):
  sns.countplot(data=df, x=col, ax=axes[i], order=df[col].value_counts().index)
  axes[i].set_title(f'Distribution of {col}', fontsize = 17)
  axes[i].set_ylabel('Count')
  axes[i].tick_params(axis='x')
  axes[i].grid(True)
plt.tight_layout()
plt.show()

# %%
cols = ['Family_Members', 'Age_in_years', 'Experience_years']
# Set up the figure and axes
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))
# Plot univariate distributions for each column
for i, col in enumerate(cols):
  if df[col].dtype in ['int64', 'float64']:
    sns.histplot(data=df, x=col, ax=axes[i], bins=30, kde=True , color ='lightgreen')
  else:
    sns.countplot(data=df, x=col, ax=axes[i], order=df[col].value_counts().index , color ='green')
    axes[i].set_title(f'Distribution of {col}', fontsize = 18)
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x')
    axes[i].grid(True)
plt.tight_layout()

# %%
plt.subplot(1,2,1)
sns.histplot(data=df, x='Annual_income',kde=True)
plt.axvline(x=df['Annual_income'].mean(),color="red",label="Mean")
plt.axvline(x=df['Annual_income'].median(),color="green",label="Median")
plt.grid()
plt.legend()
plt.subplot(1,2,2) # nrows=1, ncols=2
sns.boxplot(data=df, x='Annual_income')
plt.subplots_adjust(right=2.0)
plt.grid()
plt.show()

# %%
plt.subplot(1,2,1)
sns.histplot(data=df, x='Experience_years',kde=True)
plt.axvline(x=df['Experience_years'].mean(),color="red",label="Mean")
plt.axvline(x=df['Experience_years'].median(),color="green",label="Median")
plt.legend()
plt.grid()
plt.subplot(1,2,2)
sns.boxplot(data=df, x='Experience_years')
plt.subplots_adjust(right=2.0)
plt.grid()
plt.show()

# %%
plt.figure(figsize =(5,4))
sns.countplot(data=df, x='label')
plt.title("Distribution of Output Variable")
plt.grid()
plt.show()

# %%
cols = ['Gender', 'Car_Owner', 'Property_owner', 'Income_type', 'Education', 'Marital_status', 'Housing_type', "Occupation_type"]
fig, axes = plt.subplots(4, 2, figsize=(17, 25))
fig.tight_layout(pad=5)
# Loop through each categorical feature and create a boxplot
for i, ax in enumerate(axes.ravel()):
  if i < len(cols):
    sns.boxplot(data=df, x=cols[i], y='Annual_income', ax=ax)
    ax.set_title(cols[i] + ' vs Annual_income', fontsize = 15)
    ax.tick_params(axis='x')
    ax.grid(True)
plt.show()

# %% [markdown]
# Despite a higher number of female applicants, males generally have a greater income.
# Higher-income applicants are more likely to own cars. The ownership of property doesn't significantly influence the average income.
# Those with an academic degree tend to have the highest annual incomes.
# Additionally, managers and drivers earn more compared to other occupations.
# Applicants with a higher annual income often reside in rented apartments, irrespective of their marital status.

# %%
cols = ['Gender', 'Car_Owner', 'Property_owner', 'Income_type', 'Education', 'Marital_status', 'Housing_type', 'Occupation_type']
fig, axes = plt.subplots(4, 2, figsize=(17, 25))
fig.tight_layout(pad=5)
# Loop through each categorical feature and create a boxplot
for i, ax in enumerate(axes.ravel()):
  if i < len(cols):
    sns.boxplot(data=df, x=cols[i], y='Experience_years', ax=ax)
    ax.set_title(cols[i] + ' vs Experience_years', fontsize = 15)
    ax.tick_params(axis='x')
    ax.grid(True)
plt.show()

# %%
features=['Annual_income','Children','Family_Members','Age_in_years', 'Experience_years']
df[features].corr()
# Out:
#                   Annual_income  Children  Family_Members  Age_in_years  \
# Annual_income          1.000000  0.078497        0.050957     -0.111638
# Children               0.078497  1.000000        0.890248     -0.279716
# Family_Members         0.050957  0.890248        1.000000     -0.266527
# Age_in_years          -0.111638 -0.279716       -0.266527      1.000000
# Experience_years      -0.160761 -0.219686       -0.238907      0.627239
#
#                   Experience_years
# Annual_income            -0.160761
# Children                 -0.219686
# Family_Members           -0.238907
# Age_in_years              0.627239
# Experience_years          1.000000

# %%
plt.figure(figsize = (10,6))
sns.heatmap(df[features].corr(), annot=True , cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Children and Family members have linear corelation, that means more no of children results in more members in the family,so one of
# these features should be dropped
# Age and experience also show some corelation

# %% [markdown]
# # Section 5 :**Missing Values Imputations**

# %%
df.isnull().sum()
# Out:
# Ind_ID                0
# Gender                7
# Car_Owner             0
# Property_owner        0
# Children              0
# Annual_income        23
# Income_type           0
# Education             0
# Marital_status        0
# Housing_type          0
# Birthday_count       22
# Employed_days         0
# Mobile_phone          0
# Work_Phone            0
# Phone                 0
# Email_ID              0
# Occupation_type     488
# Family_Members        0
# label                 0
# Age_in_years         22
# Experience_years      0
# dtype: int64

# %%
df["Gender"].isnull().sum()
# Out:
# 7

# %%
df["Gender"].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
# Impute missing values in 'Gender' column with the mode (most frequent value)
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
df["Gender"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
df["Annual_income"].isnull().sum()
# Out:
# 23

# %%
mean_inc_byincome_type = df.groupby(['Income_type'])['Annual_income'].mean()
mean_inc_byincome_type
# Out:
# Income_type
# Commercial associate    234600.000000
# Pensioner               155175.096226
# State servant           211422.413793
# Working                 181048.757306
# Name: Annual_income, dtype: float64

# %%
# Impute missing values in 'Annual_Income' column with the mean
for income_type, mean_inc in mean_inc_byincome_type.items():
    df.loc[(df['Income_type'] == income_type) & (df['Annual_income'].isna()), 'Annual_income'] = mean_inc

# Check for missing values in 'Annual_income' and 'Age_in_years' columns
print(df["Annual_income"].isnull().sum())
print(df["Age_in_years"].isnull().sum())
# Out:
# 0
# 22

# %%
df["Annual_income"].isnull().sum()
# Out:
# 0

# %%
df["Age_in_years"].isnull().sum()
# Out:
# 22

# %%
mean_income_type = df.groupby(['Income_type'])['Age_in_years'].mean()
mean_income_type
# Out:
# Income_type
# Commercial associate    40.219428
# Pensioner               59.439648
# State servant           41.490269
# Working                 40.789276
# Name: Age_in_years, dtype: float64

# %%
# Impute missing values in 'Age_in_years' column with the mean
for income_type, mean_age in mean_income_type.items():
    df.loc[(df['Income_type'] == income_type) & (df['Age_in_years'].isna()), 'Age_in_years'] = mean_age

# %%
df["Age_in_years"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Ind_ID                0
# Gender                0
# Car_Owner             0
# Property_owner        0
# Children              0
# Annual_income         0
# Income_type           0
# Education             0
# Marital_status        0
# Housing_type          0
# Birthday_count       22
# Employed_days         0
# Mobile_phone          0
# Work_Phone            0
# Phone                 0
# Email_ID              0
# Occupation_type     488
# Family_Members        0
# label                 0
# Age_in_years          0
# Experience_years      0
# dtype: int64

# %%
#dropping the column as there are many missing values
df.drop(columns = ['Occupation_type'] , inplace = True)

# %%
df.drop(columns = ['Birthday_count'] , inplace = True)

# %%
df.isnull().sum()
# Out:
# Ind_ID              0
# Gender              0
# Car_Owner           0
# Property_owner      0
# Children            0
# Annual_income       0
# Income_type         0
# Education           0
# Marital_status      0
# Housing_type        0
# Employed_days       0
# Mobile_phone        0
# Work_Phone          0
# Phone               0
# Email_ID            0
# Family_Members      0
# label               0
# Age_in_years        0
# Experience_years    0
# dtype: int64

# %%
df.shape
# Out:
# (1548, 19)

# %%
df.head()
# Out:
#     Ind_ID Gender Car_Owner Property_owner  Children  Annual_income  \
# 0  5008827      M         Y              Y         0       180000.0
# 1  5009744      F         Y              N         0       315000.0
# 2  5009746      F         Y              N         0       315000.0
# 3  5009749      F         Y              N         0       234600.0
# 4  5009752      F         Y              N         0       315000.0
#
#             Income_type         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Employed_days  Mobile_phone  Work_Phone  Phone  Email_ID  Family_Members  \
# ...

# %% [markdown]
# Now we have 0 missing values

# %% [markdown]
# # **Section 6: Outlier Treatment**

# %%
#Annual_income Column

plt.subplot(1,2,1)
sns.histplot(data=df, x='Annual_income',kde=True)
plt.axvline(x=df['Annual_income'].mean(),color="red",label="Mean")
plt.axvline(x=df['Annual_income'].median(),color="green",label="Median")
plt.grid()
plt.legend()
plt.subplot(1,2,2) # nrows=1, ncols=2
sns.boxplot(data=df, x='Annual_income')
plt.subplots_adjust(right=2.0)
plt.grid()
plt.show()

# %%
#Using IQR method to handle the outliers

Q1 = np.percentile(df['Annual_income'],25)
Q3 = np.percentile(df['Annual_income'],75)
IQR=Q3-Q1

# %%
# checking value of upper limit
upper_limit = Q3+1.5*IQR
upper_limit
# Out:
# 380250.0

# %%
# applying upperlimit value
df = df[df['Annual_income'] < upper_limit]

# %%
# Verifying by plotting the distribution and box plot after handling outlers
plt.subplot(1,2,1)
sns.histplot(data=df, x='Annual_income',kde=True)
plt.axvline(x=df['Annual_income'].mean(),color="red",label="Mean")
plt.axvline(x=df['Annual_income'].median(),color="green",label="Median")
plt.grid()
plt.legend()
plt.subplot(1,2,2) # nrows=1, ncols=2
sns.boxplot(data=df, x='Annual_income')
plt.subplots_adjust(right=2.0)
plt.grid()
plt.show()

# %%
#experience year column
plt.subplot(1,2,1)
sns.histplot(data=df, x='Experience_years',kde=True)
plt.axvline(x=df['Experience_years'].mean(),color="red",label="Mean")
plt.axvline(x=df['Experience_years'].median(),color="green",label="Median")
plt.legend()
plt.grid()
plt.subplot(1,2,2)
sns.boxplot(data=df, x='Experience_years')
plt.subplots_adjust(right=2.0)
plt.grid()
plt.show()

# %%
#using IQR method to treat the outliears
Q1 = np.percentile(df['Experience_years'], 25 , interpolation='midpoint')
Q3 = np.percentile(df['Experience_years'], 75 ,interpolation='midpoint')
IQR = Q3-Q1

# %%
#checking for upper limit value
upper_limit = Q3+1.5*IQR
upper_limit
# Out:
# 38.64520547945206

# %%
# applying upperlimit value
df = df[df['Experience_years'] < upper_limit]

# %%
# verifying the distribution and box plot after handling outlers
plt.subplot(1,2,1)
sns.histplot(data=df, x='Experience_years',kde=True)
plt.axvline(x=df['Experience_years'].mean(),color="red",label="Mean")
plt.axvline(x=df['Experience_years'].median(),color="green",label="Median")
plt.legend()
plt.grid()
plt.subplot(1,2,2)
sns.boxplot(data=df, x='Experience_years')
plt.subplots_adjust(right=2.0)
plt.grid()
plt.show()

# %%
df['Experience_years'] = np.sqrt(df['Experience_years'])

# %%
# verifying the distribution and box plot after handling outlers
plt.subplot(1,2,1)
sns.histplot(data=df, x='Experience_years',kde=True)
plt.axvline(x=df['Experience_years'].mean(),color="red",label="Mean")
plt.axvline(x=df['Experience_years'].median(),color="green",label="Median")
plt.legend()
plt.grid()
plt.subplot(1,2,2)
sns.boxplot(data=df, x='Experience_years')
plt.subplots_adjust(right=2.0)
plt.grid()
plt.show()

# %%
#Family member
plt.figure(figsize =(5,4))
sns.boxplot(data=df , x='Family_Members')
plt.grid()
plt.show()

# %%
# removing the exterme value
df = df[df['Family_Members'] < 14]

# %%
plt.figure(figsize =(5,4))
sns.boxplot(data=df , x='Family_Members')
plt.grid()
plt.show()

# %%
df.shape
# Out:
# (1217, 19)

# %%
df.head()
# Out:
#     Ind_ID Gender Car_Owner Property_owner  Children  Annual_income  \
# 1  5009744      F         Y              N         0       315000.0
# 2  5009746      F         Y              N         0       315000.0
# 3  5009749      F         Y              N         0       234600.0
# 4  5009752      F         Y              N         0       315000.0
# 5  5009753      F         Y              N         0       315000.0
#
#             Income_type         Education Marital_status       Housing_type  \
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
# 5             Pensioner  Higher education        Married  House / apartment
#
#    Employed_days  Mobile_phone  Work_Phone  Phone  Email_ID  Family_Members  \
# ...

# %%
# Expoting to CSV file This will be used for solving Sql problems
df.to_csv('cleaned_data.csv')

# %% [markdown]
# Dropping the columns
# Children : Children and family_members are corelated to each other, so dropping.
# Mobile_phone : No variation in data, contains single category value only

# %%
df = df.drop(columns=['Children','Mobile_phone'])

# %%
df.shape
# Out:
# (1217, 17)

# %% [markdown]
# # **Section 7: Machine Learning approach**

# %%
#transforming the feature using binary encoding for gender column
df['Gender'] = df['Gender'].map({'M':1,'F':0})
# for Car_Owner column
df['Car_Owner'] = df['Car_Owner'].map({'Y':1,'N':0})
# for Property_owner column
df['Property_owner'] = df['Property_owner'].map({'Y':1,'N':0})

# %%
df.sample(5)
# Out:
#        Ind_ID  Gender  Car_Owner  Property_owner  Annual_income  \
# 1462  5068811       0          0               1  315000.000000
# 561   5024636       0          0               1  181048.757306
# 1334  5146045       0          0               1  360000.000000
# 272   5066597       0          0               0  360000.000000
# 673   5046003       0          0               1  225000.000000
#
#                Income_type                      Education  \
# 1462  Commercial associate  Secondary / secondary special
# 561                Working  Secondary / secondary special
# 1334  Commercial associate  Secondary / secondary special
# 272   Commercial associate               Higher education
# 673                Working  Secondary / secondary special
#
#             Marital_status       Housing_type  Employed_days  Work_Phone  \
# 1462               Married  House / apartment          -2423           0
# 561                Married  House / apartment          -1128           0
# ...

# %%
df['Education'].value_counts()
# Out:
# Secondary / secondary special    794
# Higher education                 344
# Incomplete higher                 63
# Lower secondary                   14
# Academic degree                    2
# Name: Education, dtype: int64

# %%
# importing ordinal encoder
from sklearn.preprocessing import OrdinalEncoder
# values to ordinal
cols_order = ['Lower secondary','Secondary / secondary special','Incomplete higher','Higher education', 'Academic degree']
x = OrdinalEncoder(categories=[cols_order])
df['Education'] = x.fit_transform(df[['Education']])

# %%
df.sample(5)
# Out:
#        Ind_ID  Gender  Car_Owner  Property_owner  Annual_income  \
# 441   5137022       0          0               0       180000.0
# 876   5114544       0          0               1       166500.0
# 1401  5045623       0          0               1       270000.0
# 508   5041474       0          0               1        90000.0
# 723   5096169       0          0               0       112500.0
#
#                Income_type  Education Marital_status       Housing_type  \
# 441          State servant        1.0          Widow  House / apartment
# 876                Working        2.0        Married  House / apartment
# 1401         State servant        1.0        Married  House / apartment
# 508   Commercial associate        3.0        Married  House / apartment
# 723   Commercial associate        1.0        Married  House / apartment
#
#       Employed_days  Work_Phone  Phone  Email_ID  Family_Members  label  \
# ...

# %%
# columns to onehot encoding
one_cols = df[['Income_type','Marital_status','Housing_type']]
df = pd.get_dummies(df, columns=['Income_type','Marital_status','Housing_type'],drop_first=True)

# %%
df.sample(5)
# Out:
#        Ind_ID  Gender  Car_Owner  Property_owner  Annual_income  Education  \
# 284   5095356       0          0               0       157500.0        1.0
# 760   5135779       0          0               1       126000.0        1.0
# 348   5022308       0          0               1        90000.0        1.0
# 90    5079167       1          1               0       202500.0        1.0
# 1191  5069199       0          1               1       225000.0        1.0
#
#       Employed_days  Work_Phone  Phone  Email_ID  ...  Income_type_Working  \
# 284           -1039           0      0         0  ...                    1
# 760           -2147           0      1         0  ...                    1
# 348           -3319           0      0         0  ...                    1
# 90            -1394           0      0         0  ...                    1
# 1191          -3246           0      0         0  ...                    0
#
#       Marital_status_Married  Marital_status_Separated  \
# ...

# %%
df.columns
# Out:
# Index(['Ind_ID', 'Gender', 'Car_Owner', 'Property_owner', 'Annual_income',
#        'Education', 'Employed_days', 'Work_Phone', 'Phone', 'Email_ID',
#        'Family_Members', 'label', 'Age_in_years', 'Experience_years',
#        'Income_type_Pensioner', 'Income_type_State servant',
#        'Income_type_Working', 'Marital_status_Married',
#        'Marital_status_Separated', 'Marital_status_Single / not married',
#        'Marital_status_Widow', 'Housing_type_House / apartment',
#        'Housing_type_Municipal apartment', 'Housing_type_Office apartment',
#        'Housing_type_Rented apartment', 'Housing_type_With parents'],
#       dtype='object')

# %%
df.shape
# Out:
# (1217, 26)

# %%
df.to_csv('Credit_upload.csv', )

# %%
#dealing with imbalance in the dataset
plt.figure(figsize = (5,4))
sns.countplot( data= df, x ='label')
plt.title("Distribution of Output variable)")
plt.grid()
plt.show()

# %%
# checking unique values
df['label'].value_counts()
# Out:
# 0    1095
# 1     122
# Name: label, dtype: int64

# %%
df.drop(columns = ['Employed_days'] , inplace = True )

# %%
df.isnull().sum()
# Out:
# Ind_ID                                 0
# Gender                                 0
# Car_Owner                              0
# Property_owner                         0
# Annual_income                          0
# Education                              0
# Work_Phone                             0
# Phone                                  0
# Email_ID                               0
# Family_Members                         0
# label                                  0
# Age_in_years                           0
# Experience_years                       0
# Income_type_Pensioner                  0
# Income_type_State servant              0
# Income_type_Working                    0
# Marital_status_Married                 0
# Marital_status_Separated               0
# Marital_status_Single / not married    0
# Marital_status_Widow                   0
# Housing_type_House / apartment         0
# Housing_type_Municipal apartment       0
# Housing_type_Office apartment          0
# ...

# %%
X = df.drop(columns=['label'])
y = df['label']
# importing SMOTE
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
# checking values after applying smote
y.value_counts()
# Out:
# 1    1095
# 0    1095
# Name: label, dtype: int64

# %%
# train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.20, random_state=10)

# %%
# training data
X_train.shape
# Out:
# (1752, 24)

# %%
# test data
X_test.shape
# Out:
# (438, 24)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# #  **Section 8: Model Training**

# %%
# Required imports
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score ,roc_auc_score
# Initialize the classifiers
log_reg = LogisticRegression(max_iter=1000, random_state=10)
dtc = DecisionTreeClassifier(random_state=10)
rfc = RandomForestClassifier(random_state=42)
xgb = XGBClassifier(random_state=10, use_label_encoder=False, eval_metric='logloss')
svc = SVC(random_state=10)
knn = KNeighborsClassifier()

# %%
# Dictionary to store results
results = {}
# List of classifiers
classifiers = [('Logistic Regression', log_reg),
('Decision Tree', dtc),
('Random Forest', rfc),
('XGBoost', xgb),
('Support Vector Machine', svc),
('K-Nearest Neighbors', knn)]
# Train, predict, and store results
for name, clf in classifiers:
  clf.fit(X_train_scaled, y_train)
  y_pred = clf.predict(X_test_scaled)
  accuracy = accuracy_score(y_test, y_pred)
  precision = precision_score(y_test, y_pred)
  recall = recall_score(y_test, y_pred)
  f1 = f1_score(y_test, y_pred)
  roc_auc_test = roc_auc_score(y_test, y_pred)
  results[name] = [accuracy, precision, recall, f1 , roc_auc_test]

# %%
# Convert the results dictionary to a DataFrame for better visualization
results_df = pd.DataFrame(results, index=['Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC AUC Score']).T
results_df
# Out:
#                         Accuracy  Precision    Recall  F1-Score  ROC AUC Score
# Logistic Regression     0.760274   0.761682  0.751152  0.756381       0.760191
# Decision Tree           0.858447   0.813765  0.926267  0.866379       0.859061
# Random Forest           0.942922   0.948598  0.935484  0.941995       0.942855
# XGBoost                 0.929224   0.911504  0.949309  0.930023       0.929406
# Support Vector Machine  0.810502   0.828431  0.778802  0.802850       0.810215
# K-Nearest Neighbors     0.847032   0.777778  0.967742  0.862423       0.848124

# %% [markdown]
# Final model for this is Random forest classifier as its performing best among all

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# %%
# Predict using the trained XGBoost model
y_pred_rfc = rfc.predict(X_test_scaled)
# Confusion Matrix
cm_rfc = confusion_matrix(y_test, y_pred_rfc)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_rfc, display_labels=rfc.classes_)
plt.figure(figsize=(6,6))
disp.plot(cmap='Blues', values_format='.0f')
plt.title("Confusion Matrix for Random Forest")
plt.grid(False)
plt.show()
print("\n")
# Classification Report
print("Classification Report for Random forest:\n")
print(classification_report(y_test, y_pred_rfc))
# Out:
# Classification Report for Random forest:
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       221
#            1       0.95      0.94      0.94       217
#
#     accuracy                           0.94       438
#    macro avg       0.94      0.94      0.94       438
# weighted avg       0.94      0.94      0.94       438

# %%
#Hyperparameter Tuning

from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Parameter grid for Random Forest Classifier
param_grid_rf = {
    'n_estimators': [50, 100, 150, 200],
    'max_depth': [3, 4, 5, 6],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Initialize Random Forest Classifier
clf_rf = RandomForestClassifier(random_state=10)
grid_search_rf = GridSearchCV(clf_rf, param_grid_rf, scoring='accuracy', cv=5, verbose=1, n_jobs=-1)

# Fit GridSearchCV for Random Forest Classifier
grid_search_rf.fit(X_train_scaled, y_train)
print(grid_search_rf.best_params_)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# {'bootstrap': True, 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 150}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Best hyperparameters found using GridSearchCV for Random Forest Classifier
rfc_best = RandomForestClassifier(
    n_estimators=200,
    max_depth=6,
    min_samples_split=2,
    min_samples_leaf=1,
    bootstrap=True,
    random_state=10
)

# Train the Random Forest model
rfc_best.fit(X_train_scaled, y_train)

# Predict on the test set
y_pred_best_rf = rfc_best.predict(X_test_scaled)

# Calculate and print the metrics
accuracy_best_rf = accuracy_score(y_test, y_pred_best_rf)
precision_best_rf = precision_score(y_test, y_pred_best_rf)
recall_best_rf = recall_score(y_test, y_pred_best_rf)
f1_best_rf = f1_score(y_test, y_pred_best_rf)
roc_auc_best_rf = roc_auc_score(y_test, y_pred_best_rf)

print(f"Accuracy after Hyperparameter Tuning: {accuracy_best_rf}")
print(f"Precision after Hyperparameter Tuning: {precision_best_rf}")
print(f"Recall after Hyperparameter Tuning: {recall_best_rf}")
print(f"F1-Score after Hyperparameter Tuning: {f1_best_rf}")
print(f"ROC AUC Score after Hyperparameter Tuning: {roc_auc_best_rf}")
# Out:
# Accuracy after Hyperparameter Tuning: 0.860730593607306
# Precision after Hyperparameter Tuning: 0.8362068965517241
# Recall after Hyperparameter Tuning: 0.8940092165898618
# F1-Score after Hyperparameter Tuning: 0.8641425389755011
# ROC AUC Score after Hyperparameter Tuning: 0.8610317576161978

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Obtain the confusion matrix for Random Forest
conf_matrix_rf = confusion_matrix(y_test, y_pred_best_rf)

# Visualize the confusion matrix for Random Forest
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix_rf, annot=True, fmt='g', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - Random Forest')
plt.show()

# %%
import joblib

# Save the Random Forest model
joblib.dump(rfc_best, 'random_forest_model.pkl')

# Load the Random Forest model
loaded_rfc_model = joblib.load('random_forest_model.pkl')

# %% [markdown]
# feature importance

# %%
# Calculating feature importances for Random Forest
feature_importances_rf = rfc_best.feature_importances_

# Sort the feature importances in descending order and get the indices
sorted_indices_rf = np.argsort(feature_importances_rf)[::-1]

# Plotting feature importances for Random Forest
plt.figure(figsize=(12, 8))
plt.title("Feature Importance - Random Forest")
plt.bar(X.columns[sorted_indices_rf], feature_importances_rf[sorted_indices_rf])
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# # **Section 9: SQL**
#
# all codes for this are in the sql workbench script file which is uploaded separately with the zip folder

# %% [markdown]
# # **Section 10: Final Conclusion and recommendation**

# %% [markdown]
# **1. Model Performance Ranking:**
#    In our comparative analysis of various machine learning models, Random Forest emerged as the top-performing model, exhibiting impressive accuracy (94.29%) and consistently high scores across precision (94.86%), recall (93.55%), F1-score (94.20%), and ROC AUC (94.29%). This establishes Random Forest as a robust and reliable choice for our predictive modeling task.
#
# **2. Decision Tree's Strong Recall:**
#    The Decision Tree model demonstrated remarkable recall (92.63%), emphasizing its effectiveness in capturing true positive instances. While achieving competitive precision (81.38%) and accuracy (85.84%), its recall score highlights its ability to identify a substantial portion of positive cases.
#
# **3. XGBoost's Balanced Performance:**
#    XGBoost showcased a balanced performance, securing a high ROC AUC score (92.94%) and competitive precision (91.15%) and recall (94.93%). This indicates its suitability for scenarios where a balanced consideration of false positives and false negatives is crucial.
#
# **4. Logistic Regression's Reliability:**
#    Logistic Regression, while having a slightly lower accuracy (76.03%), exhibited a consistent and balanced performance across precision (76.17%), recall (75.12%), F1-score (75.64%), and ROC AUC (76.02%). Its reliability makes it a viable choice for scenarios where interpretability is essential.
#
# **5. Support Vector Machine's Trade-off:**
#    The Support Vector Machine demonstrated a trade-off between precision (82.84%) and recall (77.88%), striking a balance that may be suitable for applications where managing false positives and false negatives is equally important. Further optimizations may enhance its overall performance.
#
# In conclusion, the choice of the best model should be aligned with specific objectives and considerations, and Random Forest stands out as a strong candidate for achieving a well-balanced and high-performing solution in this context.

# %% [markdown]
# # Submitted by: Khushboo Gangwani
# # DS38A batch
# # Student ID: S5941
